# %%
import pandas as pd

# %%
latents_csv = pd.read_csv("/mnt/d/lding/CLS_GitHub/SubCellAE/results/ae_run/baseline_AE/latents.csv")

# %%
latents_csv
# Out:
#                               filename  \
# 0      control_f0001x0112y0496ps32.tif
# 1      control_f0001x0144y0464ps32.tif
# 2      control_f0001x0144y0496ps32.tif
# 3      control_f0001x0176y0464ps32.tif
# 4      control_f0001x0176y0496ps32.tif
# ...                                ...
# 23651    ycomp_f0038x1040y0400ps32.tif
# 23652    ycomp_f0038x1040y0432ps32.tif
# 23653    ycomp_f0038x1072y0176ps32.tif
# 23654    ycomp_f0038x1072y0208ps32.tif
# 23655    ycomp_f0038x1072y0336ps32.tif
#
#                                                 filepath  condition  \
# 0      /mnt/d/lding/FA/analysis_results/FA_ML_Annabel...          0
# 1      /mnt/d/lding/FA/analysis_results/FA_ML_Annabel...          0
# 2      /mnt/d/lding/FA/analysis_results/FA_ML_Annabel...          0
# 3      /mnt/d/lding/FA/analysis_results/FA_ML_Annabel...          0
# 4      /mnt/d/lding/FA/analysis_results/FA_ML_Annabel...          0
# ...                                                  ...        ...
# ...

# %%
label_csv =pd.read_csv("/mnt/d/lding/FA/analysis_results/labelling/paxdata_paxpatch_batch1and2_combined_labels.csv")

# %%
label_csv
# Out:
#                             unique_ID        crop_img_filename    group  \
# 0     control-f0001x0592y0560ps32.tif  f0001x0592y0560ps32.tif  control
# 1     control-f0001x0688y0848ps32.tif  f0001x0688y0848ps32.tif  control
# 2     control-f0001x0592y0592ps32.tif  f0001x0592y0592ps32.tif  control
# 3     control-f0001x0368y0528ps32.tif  f0001x0368y0528ps32.tif  control
# 4     control-f0001x0592y0528ps32.tif  f0001x0592y0528ps32.tif  control
# ...                               ...                      ...      ...
# 1335    ycomp-f0034x0272y0240ps32.tif  f0034x0272y0240ps32.tif    ycomp
# 1336    ycomp-f0035x0624y0976ps32.tif  f0035x0624y0976ps32.tif    ycomp
# 1337    ycomp-f0035x0496y0688ps32.tif  f0035x0496y0688ps32.tif    ycomp
# 1338    ycomp-f0035x0720y0848ps32.tif  f0035x0720y0848ps32.tif    ycomp
# 1339    ycomp-f0035x0688y0368ps32.tif  f0035x0688y0368ps32.tif    ycomp
#
#       group_ID              Position    classification
# ...
